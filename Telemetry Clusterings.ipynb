# %%
# !pip install azure-identity azure-mgmt-resource azure-storage-blob pandas scikit-learn matplotlib
# Out:
# Requirement already satisfied: azure-identity in c:\users\ryanb\anaconda3\lib\site-packages (1.24.0)
# Requirement already satisfied: azure-mgmt-resource in c:\users\ryanb\anaconda3\lib\site-packages (24.0.0)
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.26.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: pandas in c:\users\ryanb\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\ryanb\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\ryanb\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: azure-core>=1.31.0 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-identity) (1.35.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-identity) (43.0.0)
# Requirement already satisfied: msal>=1.30.0 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-identity) (1.33.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-identity) (4.11.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-mgmt-resource) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-mgmt-resource) (1.1.28)
# Requirement already satisfied: azure-mgmt-core>=1.5.0 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-mgmt-resource) (1.6.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ryanb\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ryanb\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ryanb\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ryanb\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ryanb\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ryanb\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ryanb\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ryanb\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ryanb\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ryanb\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ryanb\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ryanb\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ryanb\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ryanb\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\ryanb\anaconda3\lib\site-packages (from azure-core>=1.31.0->azure-identity) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\ryanb\anaconda3\lib\site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\ryanb\anaconda3\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.8.0)
# Requirement already satisfied: pycparser in c:\users\ryanb\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ryanb\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ryanb\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ryanb\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ryanb\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.1.31)
# Downloading azure_storage_blob-12.26.0-py3-none-any.whl (412 kB)
# Installing collected packages: azure-storage-blob
# Successfully installed azure-storage-blob-12.26.0

# %% [markdown]
# ## Imports:

# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd
from io import BytesIO, StringIO
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Configuration:

# %%
AZURE_CONNECTION_STRING = "DefaultEndpointsProtocol=https;AccountName=totsvisiodb;AccountKey=XT1NpUL9UrN+2bTCRV6qEqcts0Psweg8o96hrlsnxgNR2CeOhIkPFU2yU/0CtxABmTTLqJkHN3zg+AStVIGOeg==;EndpointSuffix=core.windows.net"
CONTAINER_NAME = "csvs-tratados-gpt"
COLUMNS = ["CLIENTE_ID", "EVENT_DURATION"]

# Inicializa o cliente do Blob
blob_service_client = BlobServiceClient.from_connection_string(AZURE_CONNECTION_STRING)

# %% [markdown]
# ## Clients Summary Dataframe Creation

# %%
# Lista de CSVs
csv_files = [f"tratado_telemetria_{i}.csv" for i in range(1, 12)]

# Dicionário para acumular os resultados por cliente
resumo_clientes = {}

for BLOB_NAME in csv_files:
    blob_client = blob_service_client.get_blob_client(CONTAINER_NAME, BLOB_NAME)
    stream = blob_client.download_blob()
    
    for chunk in pd.read_csv(BytesIO(stream.readall()), usecols=COLUMNS, chunksize=100_000):
        # Agrupa por cliente neste chunk
        grouped = chunk.groupby("CLIENTE_ID")["EVENT_DURATION"].agg(
            total_event_duration="sum",
            avg_event_duration="mean",
            num_events="count"
        )
        
        # Acumula no dicionário
        for cliente_id, row in grouped.iterrows():
            if cliente_id in resumo_clientes:
                # Atualiza os valores existentes
                resumo_clientes[cliente_id]["total_event_duration"] += row["total_event_duration"]
                resumo_clientes[cliente_id]["num_events"] += row["num_events"]
                # Recalcula média incremental
                prev_total = resumo_clientes[cliente_id]["avg_event_duration"] * (resumo_clientes[cliente_id]["num_events"] - row["num_events"])
                resumo_clientes[cliente_id]["avg_event_duration"] = (prev_total + row["total_event_duration"]) / resumo_clientes[cliente_id]["num_events"]
            else:
                resumo_clientes[cliente_id] = row.to_dict()

# Converte para DataFrame final
df_clientes = pd.DataFrame.from_dict(resumo_clientes, orient="index").reset_index().rename(columns={"index": "CLIENTE_ID"})
df_clientes.head()
# Out:
#   CLIENTE_ID  total_event_duration  avg_event_duration  num_events
# 0   T0100800          6.941892e+06         8157.335111       851.0
# 1   T0106000          5.552706e+06         6288.454914       883.0
# 2   T0150200          7.006355e+09       195032.708328     35924.0
# 3   T0206900          5.864216e+06         3127.581961      1875.0
# 4   T0214500          1.169429e+08        15766.879079      7417.0

# %% [markdown]
# ## K-means Clustering:

# %%
# Normalização
X = df_clientes[["total_event_duration", "avg_event_duration", "num_events"]].values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# K-Means
k = 5
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X_scaled)
df_clientes['cluster'] = kmeans.labels_

print(df_clientes.head())
# Out:
# C:\Users\ryanb\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\ryanb\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\ryanb\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ryanb\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\ryanb\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   CLIENTE_ID  total_event_duration  avg_event_duration  num_events  cluster
# 0   T0100800          6.941892e+06         8157.335111       851.0        0
# 1   T0106000          5.552706e+06         6288.454914       883.0        0
# 2   T0150200          7.006355e+09       195032.708328     35924.0        4
# 3   T0206900          5.864216e+06         3127.581961      1875.0        0
# 4   T0214500          1.169429e+08        15766.879079      7417.0        0

# %% [markdown]
# ### **Clusters Analysis:**

# %%
# Estatísticas por cluster
df_clientes.groupby('cluster')[["total_event_duration", "avg_event_duration", "num_events"]].describe()
# Out:
#         total_event_duration                                            \
#                        count          mean           std           min
# cluster
# 0                     4387.0  5.360858e+07  1.142385e+09 -1.578109e+07
# 1                        1.0  1.254527e+11           NaN  1.254527e+11
# 2                        2.0  3.268387e+11  5.790939e+10  2.858906e+11
# 3                        1.0  2.562142e+11           NaN  2.562142e+11
# 4                       74.0  2.831599e+09  1.004352e+10  2.175541e+07
#
#                                                                  \
#                   25%           50%           75%           max
# cluster
# 0        6.623913e+05  3.157798e+06  1.077052e+07  6.450499e+10
# 1        1.254527e+11  1.254527e+11  1.254527e+11  1.254527e+11
# 2        3.063647e+11  3.268387e+11  3.473128e+11  3.677869e+11
# 3        2.562142e+11  2.562142e+11  2.562142e+11  2.562142e+11
# 4        8.811826e+07  1.911775e+08  4.925544e+08  7.318717e+10
#
#         avg_event_duration                ...                              \
#                      count          mean  ...           75%           max
# cluster                                   ...
# 0                   4387.0  1.233825e+04  ...  9.916055e+03  4.677665e+06
# 1                      1.0  5.807997e+07  ...  5.807997e+07  5.807997e+07
# 2                      2.0  8.524709e+06  ...  9.644233e+06  1.076376e+07
# 3                      1.0  9.060324e+05  ...  9.060324e+05  9.060324e+05
# 4                     74.0  5.799897e+04  ...  9.890870e+03  1.594909e+06
#
#         num_events                                                             \
#              count           mean           std       min       25%       50%
# cluster
# 0           4387.0    1667.721450   2897.274773       1.0     163.0     550.0
# 1              1.0    2160.000000           NaN    2160.0    2160.0    2160.0
# 2              2.0   39826.000000   8000.206122   34169.0   36997.5   39826.0
# 3              1.0  282787.000000           NaN  282787.0  282787.0  282787.0
# 4             74.0   42729.202703  25534.193448   22299.0   28154.0   33035.5
#
#
#               75%       max
# cluster
# 0          1799.0   21864.0
# 1          2160.0    2160.0
# 2         42654.5   45483.0
# 3        282787.0  282787.0
# 4         45819.0  177700.0
#
# [5 rows x 24 columns]

# %% [markdown]
# * Clusters Samples:

# %%
# Para cada cluster, pega até dois exemplos
for cluster_id in df_clientes['cluster'].unique():
    cluster_df = df_clientes[df_clientes['cluster'] == cluster_id]
    n_samples = min(2, len(cluster_df))  # pega 2 ou menos, dependendo do tamanho
    exemplos = cluster_df.sample(n=n_samples, random_state=42)
    print(f"\n=== Cluster {cluster_id} ===")
    print(exemplos)
# Out:
# === Cluster 0 ===
#      CLIENTE_ID  total_event_duration  avg_event_duration  num_events  cluster
# 2824   TFDGKO00          1.283133e+07        12337.819080      1040.0        0
# 3077   TB570700          2.955140e+05         6872.418605        43.0        0
#
# === Cluster 4 ===
#      CLIENTE_ID  total_event_duration  avg_event_duration  num_events  cluster
# 199    TEXKGG00          2.450629e+08         9995.630058     24517.0        4
# 3875   TA858300          2.064401e+08         3834.183931     53842.0        4
#
# === Cluster 2 ===
#      CLIENTE_ID  total_event_duration  avg_event_duration  num_events  cluster
# 2564   T5573700          2.858906e+11        6.285659e+06     45483.0        2
# 1320   T5361500          3.677869e+11        1.076376e+07     34169.0        2
#
# === Cluster 3 ===
#      CLIENTE_ID  total_event_duration  avg_event_duration  num_events  cluster
# 3451   T7500400          2.562142e+11       906032.385359    282787.0        3
#
# === Cluster 1 ===
#      CLIENTE_ID  total_event_duration  avg_event_duration  num_events  cluster
# 3475   TAAMJS00          1.254527e+11        5.807997e+07      2160.0        1

# %% [markdown]
# ### Graph

# %%
# Configura o plot 3D
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Cores para cada cluster
cores = ['red', 'blue', 'green', 'orange', 'purple', 'cyan', 'magenta']

# Plota cada cluster
for cluster_id in df_clientes['cluster'].unique():
    cluster_df = df_clientes[df_clientes['cluster'] == cluster_id]
    ax.scatter(
        cluster_df['total_event_duration'],
        cluster_df['avg_event_duration'],
        cluster_df['num_events'],
        label=f'Cluster {cluster_id}',
        color=cores[cluster_id % len(cores)],
        s=50, alpha=0.6
    )

# Labels e título
ax.set_xlabel('Total Event Duration')
ax.set_ylabel('Average Event Duration')
ax.set_zlabel('Number of Events')
ax.set_title('Clusters de Clientes - KMeans')
ax.legend()
plt.show()

# %% [markdown]
# ### **Clusters Dataset Definition and Loading:**

# %%
blob_clients = "tratado_dados_clientes.csv"
blob_clients_list = blob_service_client.get_blob_client(CONTAINER_NAME, BLOB_NAME)
stream = blob_clients_list.download_blob()
df_info_clientes = pd.read_csv(stream)

# %%
df_info_clientes.head()
# Out:
#   CLIENTE_ID  EVENT_DURATION  MODULO_ID  PRODUCT_LINE_ID REFERENCE_DATE_START  \
# 0   T4308700        436064.0        523                3           2025-03-19
# 1   T4308700        850705.0        534                3           2025-03-19
# 2   T4308700        440917.0        534                3           2025-03-19
# 3   T4308700        436063.0        523                3           2025-03-19
# 4   T4308700        430097.0        534                3           2025-03-19
#
#    SLOT_ID STATUS_LICENCA  TCLOUD  CLIENTE_PRIME
# 0     4001   Desconectado     NaN            NaN
# 1     4001   Desconectado     NaN            NaN
# 2     4001   Desconectado     NaN            NaN
# 3     4001   Desconectado     NaN            NaN
# 4     4001   Desconectado     NaN            NaN

# %%
telemetry_clients_clusters = pd.merge(
    df_info_clientes, 
    df_clientes, 
    on="CLIENTE_ID", 
    how="inner"
)

telemetry_clients_clusters.head()
# Out:
#   CLIENTE_ID  EVENT_DURATION  MODULO_ID  PRODUCT_LINE_ID REFERENCE_DATE_START  \
# 0   T4308700        436064.0        523                3           2025-03-19
# 1   T4308700        850705.0        534                3           2025-03-19
# 2   T4308700        440917.0        534                3           2025-03-19
# 3   T4308700        436063.0        523                3           2025-03-19
# 4   T4308700        430097.0        534                3           2025-03-19
#
#    SLOT_ID STATUS_LICENCA  TCLOUD  CLIENTE_PRIME  total_event_duration  \
# 0     4001   Desconectado     NaN            NaN          4.951026e+08
# 1     4001   Desconectado     NaN            NaN          4.951026e+08
# 2     4001   Desconectado     NaN            NaN          4.951026e+08
# 3     4001   Desconectado     NaN            NaN          4.951026e+08
# 4     4001   Desconectado     NaN            NaN          4.951026e+08
#
#    avg_event_duration  num_events  cluster
# 0          5368.65407     92221.0        4
# 1          5368.65407     92221.0        4
# 2          5368.65407     92221.0        4
# 3          5368.65407     92221.0        4
# 4          5368.65407     92221.0        4

# %% [markdown]
# ### Exportação para o container clusters.

# %% [raw]
# # 1. Converter o DataFrame para CSV em memória
# csv_buffer = StringIO()
# telemetry_clients_clusters.to_csv(csv_buffer, index=False, encoding="utf-8")
#
# # 2. Criar client para o novo container
# container_name = "clusters"
# blob_name = "telemetry_clusters.csv"
#
# # Cria o container se ainda não existir
# blob_service_client.create_container(container_name)
#
# # 3. Criar client do blob no novo container
# blob_client = blob_service_client.get_blob_client(
#     container=container_name,
#     blob=blob_name
# )
#
# # 4. Upload do CSV
# blob_client.upload_blob(csv_buffer.getvalue(), overwrite=True)
#
# print("Arquivo exportado para o container 'clusters' com sucesso!")
#
# # Código colocado como raw para evitar risco de inserção no container repetidamente

# %% [markdown]
# # **Analysis for Playbooks**

# %%
cluster_summary = df_clientes.groupby("cluster").agg(
    clientes=("CLIENTE_ID", "count"),
    total_event_duration=("total_event_duration", "mean"),
    avg_event_duration=("avg_event_duration", "mean"),
    num_events=("num_events", "mean")
).reset_index()

cluster_summary
# Out:
#    cluster  clientes  total_event_duration  avg_event_duration     num_events
# 0        0      4387          5.360858e+07        1.233825e+04    1667.721450
# 1        1         1          1.254527e+11        5.807997e+07    2160.000000
# 2        2         2          3.268387e+11        8.524709e+06   39826.000000
# 3        3         1          2.562142e+11        9.060324e+05  282787.000000
# 4        4        74          2.831599e+09        5.799897e+04   42729.202703

# %%
# Filtrar apenas os clusters 0 e 4
df_clusters_filtered = df_clientes[df_clientes["cluster"].isin([0, 4])]

# Plotar scatter plot
plt.figure(figsize=(8,6))
for cluster in [0, 4]:
    subset = df_clusters_filtered[df_clusters_filtered["cluster"] == cluster]
    plt.scatter(subset["avg_event_duration"], subset["num_events"], label=f"Cluster {cluster}", alpha=0.6)

plt.xlabel("Average Event Duration")
plt.ylabel("Number of Events")
plt.title("Comparativo Clusters 0 e 4")
plt.legend()
plt.show()

# %%
cluster_summary = df_clientes.groupby("cluster").agg(
    clientes=("CLIENTE_ID", "count"),
    total_event_duration=("total_event_duration", "mean"),
    avg_event_duration=("avg_event_duration", "mean"),
    num_events=("num_events", "mean")
).reset_index()

# Converter de ms para minutos
cluster_summary["total_event_duration_min"] = cluster_summary["total_event_duration"] / 60000
cluster_summary["avg_event_duration_min"] = cluster_summary["avg_event_duration"] / 60000

# Mostrar apenas colunas em minutos
cluster_summary[["cluster", "clientes", "total_event_duration_min", "avg_event_duration_min", "num_events"]]
# Out:
#    cluster  clientes  total_event_duration_min  avg_event_duration_min  \
# 0        0      4387              8.934763e+02                0.205637
# 1        1         1              2.090879e+06              967.999451
# 2        2         2              5.447312e+06              142.078476
# 3        3         1              4.270236e+06               15.100540
# 4        4        74              4.719332e+04                0.966649
#
#       num_events
# 0    1667.721450
# 1    2160.000000
# 2   39826.000000
# 3  282787.000000
# 4   42729.202703

# %% [markdown]
# ### 🔎 **Análise dos clusters**
#
# #### **Cluster 0 (4387 clientes)**
#
# * **Maioria esmagadora dos clientes**.
# * `avg_event_duration ≈ 12k` → eventos relativamente curtos.
# * `num_events ≈ 1.6k` → uso moderado, volume de eventos bem menor que outros clusters.
# * **Conclusão:** clientes "padrão", baixo a médio consumo, provavelmente a base do negócio.
#
# ---
#
# #### **Cluster 4 (74 clientes)**
#
# * Poucos clientes, mas:
# * `avg_event_duration ≈ 58k` (5x maior que o cluster 0).
# * `num_events ≈ 42k` (!!), muito maior que o cluster 0.
# * **Conclusão:** heavy users, muito engajados, uso intenso da plataforma.
#
# ---
#
# #### **Cluster 1 (1 cliente isolado)**
#
# * Duração média **muito alta** (`58M`), mas só `2160 eventos`.
# * Parece **outlier** (uso anômalo, um caso extremo).
#
# ---
#
# #### **Cluster 2 (2 clientes)**
#
# * `num_events ≈ 40k` mas duração média `≈ 8.5M`.
# * Também outliers, com comportamento atípico de eventos **extremamente longos**.
#
# ---
#
# #### **Cluster 3 (1 cliente isolado)**
#
# * `num_events ≈ 280k`, mas duração média "baixa" (`≈ 900k` comparado aos outros outliers).
# * Outro **outlier único**.
#
# ---
#
# ### 📌 Conclusões gerais
#
# * **Cluster 0:** representa **a massa normal de clientes**, baixa/média intensidade.
# * **Cluster 4:** representa um grupo **pequeno mas valioso**, heavy users.
# * **Clusters 1, 2 e 3:** são **outliers** (clientes específicos com padrões bizarros).
#   → Esses podem ser investigados individualmente, porque distorcem a média e provavelmente não vale tratar como grupo.
#
# ---
#
# ### 🛠️ Recomendações (Playbooks)
#
# #### **Para o Cluster 0 (base de clientes)**
#
# * **Onboarding & Educação:**
#   Criar tutoriais, materiais e incentivos para aumentar o engajamento.
# * **Campanhas de upsell:**
#   Oferecer funcionalidades premium ou planos que aumentem o consumo.
# * **Monitoramento de churn:**
#   Como são clientes de baixo uso, estão mais propensos a churn → monitorar inatividade.
#
# ---
#
# #### **Para o Cluster 4 (heavy users)**
#
# * **Retenção VIP:**
#   Criar programa especial de suporte/benefícios (ex: atendimento prioritário, descontos em upgrades).
# * **Feedback contínuo:**
#   Esses clientes são ideais para entrevistas, testes beta, coleta de sugestões.
# * **Infraestrutura & Performance:**
#   Garantir que o uso intenso deles não gere gargalos → talvez oferecer planos dedicados.
# * **Monetização extra:**
#   Avaliar precificação diferenciada (esses clientes provavelmente têm maior disposição a pagar).
#
# ---
#
# #### **Para os outliers (Clusters 1, 2, 3)**
#
# * **Investigação manual:**
#   Pode ser erro de telemetria, bug ou uso muito fora do comum.
# * **Ajuste de modelo:**
#   Dependendo do objetivo, você pode até **excluir esses clientes** na próxima rodada de clustering, porque eles distorcem os centroides.
#
# ---
#
# 👉 Resumindo:
#
# * **Cluster 0 = massa (retenção + aumento de uso).**
# * **Cluster 4 = heavy users (retenção premium + monetização).**
# * **Clusters 1,2,3 = outliers (investigar e tratar separadamente).**

# %% [markdown]
# # Pipeline de Tratamento & Upload para Azure
#
# ## Boas práticas aplicadas
# - Parâmetros centralizados
# - Logs estruturados
# - Tratamento defensivo (`try/except`)
# - Funções puras e reutilizáveis
# - Normalização de colunas (snake_case), **strip** de strings
# - Conversão conservadora de datas
# - Remoção de duplicatas
# - Relatório de transformações por arquivo
# - Upload para Azure em prefixo único por execução (ex.: `processed/AAAA-MM-DD_HHMMSS/`)
# - Instalação condicional de dependências

# %% [markdown]
# > Se precisar instalar dependências, use a célula abaixo. **Opcional**.

# %%
# %% [markdown]
# Instalação de dependências (execute se necessário)
# - azure-storage-blob
# - pandas (opcional, caso use o bloco de tratamento)
#
# Dica: em ambientes corporativos, prefira instalar via conda/anaconda.
# !pip install --quiet azure-storage-blob pandas

# %% [markdown]
# ## Configuração e logging

# %%
from pathlib import Path
import logging, datetime
from typing import List

# === Caminhos (Windows) ===
INPUT_DIR = Path("dados_originais")
OUTPUT_DIR = Path("dados_tratados")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Prefixo único da execução (termina com '/')
RUN_PREFIX = datetime.datetime.now().strftime("processed/%Y-%m-%d_%H%M%S/")

# Logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s | %(levelname)s | %(message)s")
logger = logging.getLogger("tratamento")

logger.info("INPUT_DIR=%s | OUTPUT_DIR=%s | PREFIX=%s", INPUT_DIR, OUTPUT_DIR, RUN_PREFIX)
# Out:
# 2025-08-24 04:31:01,615 | INFO | INPUT_DIR=dados_originais | OUTPUT_DIR=dados_tratados | PREFIX=processed/2025-08-24_043101/

# %% [markdown]
# ## Verificação de arquivos CSV

# %%
# Apenas CSVs na pasta raiz. Se tiver subpastas, troque por rglob('**/*.csv')
arquivos_csv = list(INPUT_DIR.glob("*.csv"))
logger.info("Qtd CSVs encontrados: %d", len(arquivos_csv))
for p in arquivos_csv[:20]:
    logger.info(" - %s", p.name)

if not arquivos_csv:
    logger.warning("Nenhum CSV encontrado em %s", INPUT_DIR)
# Out:
# 2025-08-24 04:31:01,644 | INFO | Qtd CSVs encontrados: 23
# 2025-08-24 04:31:01,645 | INFO |  - telemetria_1.csv
# 2025-08-24 04:31:01,645 | INFO |  - telemetria_2.csv
# 2025-08-24 04:31:01,646 | INFO |  - telemetria_11.csv
# 2025-08-24 04:31:01,647 | INFO |  - nps_transacional_implantacao.csv
# 2025-08-24 04:31:01,647 | INFO |  - clientes_desde (1).csv
# 2025-08-24 04:31:01,647 | INFO |  - historico.csv
# 2025-08-24 04:31:01,648 | INFO |  - contratacoes_ultimos_12_meses.csv
# 2025-08-24 04:31:01,648 | INFO |  - nps_transacional_suporte.csv
# 2025-08-24 04:31:01,649 | INFO |  - nps_transacional_aquisicao.csv
# 2025-08-24 04:31:01,650 | INFO |  - telemetria_7.csv
# 2025-08-24 04:31:01,650 | INFO |  - telemetria_10.csv
# 2025-08-24 04:31:01,651 | INFO |  - telemetria_5.csv
# 2025-08-24 04:31:01,651 | INFO |  - dados_clientes.csv
# 2025-08-24 04:31:01,652 | INFO |  - telemetria_4.csv
# 2025-08-24 04:31:01,652 | INFO |  - telemetria_6.csv
# 2025-08-24 04:31:01,652 | INFO |  - tickets.csv
# 2025-08-24 04:31:01,653 | INFO |  - mrr.csv
# 2025-08-24 04:31:01,653 | INFO |  - telemetria_8.csv
# 2025-08-24 04:31:01,654 | INFO |  - nps_relacional.csv
# 2025-08-24 04:31:01,655 | INFO |  - nps_transacional_produto.csv

# %% [markdown]
# ## Funções utilitárias de tratamento (opcional)

# %%
# Exemplo simples de transformação: apenas copia o arquivo
# Você pode substituir por um tratamento real usando pandas, etc.
def processar_arquivo_csv(caminho: Path, pasta_saida: Path) -> Path:
    """Processa um CSV (ex.: limpeza) e grava na pasta de saída.
    No exemplo, copiamos o arquivo sem alterações.
    Retorna o caminho do CSV tratado.
    """
    destino = pasta_saida / caminho.name
    # Copia conteúdo (sem pandas para manter genérico)
    with open(caminho, 'rb') as fin, open(destino, 'wb') as fout:
        fout.write(fin.read())
    return destino

# %% [markdown]
# ## Upload para Azure Blob Storage

# %%
from azure.storage.blob import BlobServiceClient
from azure.core.exceptions import ResourceExistsError

def blob_name_from_relative(rel: Path, prefix: str) -> str:
    """Monta o nome do blob usando '/' e prefixo de execução."""
    rel_str = rel.as_posix()
    if prefix and not prefix.endswith('/'):
        prefix = prefix + '/'
    return f"{prefix}{rel_str}"

def ensure_container(container_client, logger=logger):
    try:
        container_client.create_container()
        logger.info("Container criado.")
    except ResourceExistsError:
        logger.info("Container já existe; seguindo em frente.")

# %% [markdown]
# ### Parâmetros de conexão Azure

# %%
# >>>>> EDITE AQUI <<<<<
# Use sua Connection String e o nome do container
CONNECTION_STRING = "DefaultEndpointsProtocol=https;AccountName=totsvisiodb;AccountKey=XT1NpUL9UrN+2bTCRV6qEqcts0Psweg8o96hrlsnxgNR2CeOhIkPFU2yU/0CtxABmTTLqJkHN3zg+AStVIGOeg==;EndpointSuffix=core.windows.net"
CONTAINER_NAME    = "csvs-tratados-gpt"

# Inicializa clientes
blob_service = BlobServiceClient.from_connection_string(CONNECTION_STRING)
container_client = blob_service.get_container_client(CONTAINER_NAME)
ensure_container(container_client)
# Out:
# 2025-08-24 04:31:01,729 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt?restype=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '23cf32f6-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-08-24 04:31:02,261 | INFO | Response status: 409
# Response headers:
#     'Content-Length': '230'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669a76-801e-000c-50af-14ee8b000000'
#     'x-ms-client-request-id': '23cf32f6-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-error-code': 'ContainerAlreadyExists'
#     'Date': 'Sun, 24 Aug 2025 04:31:01 GMT'
# 2025-08-24 04:31:02,263 | INFO | Container já existe; seguindo em frente.

# %% [markdown]
# ## Execução do pipeline

# %%
from datetime import datetime

enviados = 0
tratados: List[Path] = []

if not arquivos_csv:
    logger.warning("Nenhum arquivo para processar/enviar. Verifique o INPUT_DIR e o filtro (*.csv).")
else:
    # 1) Tratamento (opcional) e escrita na pasta de saída
    for p in arquivos_csv:
        tratado = processar_arquivo_csv(p, OUTPUT_DIR)
        tratados.append(tratado)
    logger.info("Tratamento concluído. %d arquivo(s) gerados em %s", len(tratados), OUTPUT_DIR)

    # 2) Upload para Azure
    for p in tratados:
        rel = p.relative_to(OUTPUT_DIR)      # nome de blob baseado na pasta de saída
        blob_name = blob_name_from_relative(rel, RUN_PREFIX)
        with open(p, "rb") as f:
            container_client.upload_blob(name=blob_name, data=f, overwrite=True)
        logger.info("Enviado para Azure: %s", blob_name)
        enviados += 1

logger.info("Upload concluído. %d arquivo(s) enviados.", enviados)
# Out:
# 2025-08-24 04:31:02,685 | INFO | Tratamento concluído. 23 arquivo(s) gerados em dados_tratados
# 2025-08-24 04:31:02,690 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_1.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '1048576'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '2461d28c-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:03,551 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:03 GMT'
#     'ETag': '"0x8DDE2C709107174"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669b50-801e-000c-09af-14ee8b000000'
#     'x-ms-client-request-id': '2461d28c-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:02 GMT'
# 2025-08-24 04:31:03,553 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_1.csv
# 2025-08-24 04:31:03,556 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_2.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '2097152'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '24e5ffc6-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:03,828 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:03 GMT'
#     'ETag': '"0x8DDE2C7093AEE7C"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669c8d-801e-000c-11af-14ee8b000000'
#     'x-ms-client-request-id': '24e5ffc6-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:03 GMT'
# 2025-08-24 04:31:03,830 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_2.csv
# 2025-08-24 04:31:03,833 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_11.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '2097152'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '25103c78-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:03,995 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:03 GMT'
#     'ETag': '"0x8DDE2C7095461F8"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669cd9-801e-000c-4eaf-14ee8b000000'
#     'x-ms-client-request-id': '25103c78-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:03 GMT'
# 2025-08-24 04:31:03,997 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_11.csv
# 2025-08-24 04:31:04,000 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/nps_transacional_implantacao.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '21595'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '2529a83e-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:04,138 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:04 GMT'
#     'ETag': '"0x8DDE2C70969FC70"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669d0b-801e-000c-7caf-14ee8b000000'
#     'x-ms-client-request-id': '2529a83e-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:03 GMT'
# 2025-08-24 04:31:04,139 | INFO | Enviado para Azure: processed/2025-08-24_043101/nps_transacional_implantacao.csv
# 2025-08-24 04:31:04,142 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/clientes_desde%20%281%29.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '201708'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '253f5a30-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:04,280 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:04 GMT'
#     'ETag': '"0x8DDE2C7097FC82C"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669d33-801e-000c-20af-14ee8b000000'
#     'x-ms-client-request-id': '253f5a30-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:03 GMT'
# 2025-08-24 04:31:04,281 | INFO | Enviado para Azure: processed/2025-08-24_043101/clientes_desde (1).csv
# 2025-08-24 04:31:04,284 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/historico.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '2097152'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '25550eca-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:04,511 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:04 GMT'
#     'ETag': '"0x8DDE2C709A33B24"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669d62-801e-000c-4baf-14ee8b000000'
#     'x-ms-client-request-id': '25550eca-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:03 GMT'
# 2025-08-24 04:31:04,512 | INFO | Enviado para Azure: processed/2025-08-24_043101/historico.csv
# 2025-08-24 04:31:04,514 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/contratacoes_ultimos_12_meses.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '117110'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '25783ae4-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:04,649 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:04 GMT'
#     'ETag': '"0x8DDE2C709B84024"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669da6-801e-000c-7eaf-14ee8b000000'
#     'x-ms-client-request-id': '25783ae4-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:03 GMT'
# 2025-08-24 04:31:04,650 | INFO | Enviado para Azure: processed/2025-08-24_043101/contratacoes_ultimos_12_meses.csv
# 2025-08-24 04:31:04,653 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/nps_transacional_suporte.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '1048576'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '258d6022-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:04,809 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:04 GMT'
#     'ETag': '"0x8DDE2C709D09FF4"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669dc5-801e-000c-19af-14ee8b000000'
#     'x-ms-client-request-id': '258d6022-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:04 GMT'
# 2025-08-24 04:31:04,810 | INFO | Enviado para Azure: processed/2025-08-24_043101/nps_transacional_suporte.csv
# 2025-08-24 04:31:04,812 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/nps_transacional_aquisicao.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '5574'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '25a5a4d4-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:04,946 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:04 GMT'
#     'ETag': '"0x8DDE2C709E579EC"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669df2-801e-000c-3faf-14ee8b000000'
#     'x-ms-client-request-id': '25a5a4d4-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:04 GMT'
# 2025-08-24 04:31:04,946 | INFO | Enviado para Azure: processed/2025-08-24_043101/nps_transacional_aquisicao.csv
# 2025-08-24 04:31:04,949 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_7.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '3145728'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '25ba9e0c-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:05,230 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:05 GMT'
#     'ETag': '"0x8DDE2C70A10BD64"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669e34-801e-000c-67af-14ee8b000000'
#     'x-ms-client-request-id': '25ba9e0c-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:04 GMT'
# 2025-08-24 04:31:05,231 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_7.csv
# 2025-08-24 04:31:05,233 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_10.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '1048576'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '25e5f516-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:05,386 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:05 GMT'
#     'ETag': '"0x8DDE2C70A289DC0"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669e93-801e-000c-32af-14ee8b000000'
#     'x-ms-client-request-id': '25e5f516-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:04 GMT'
# 2025-08-24 04:31:05,386 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_10.csv
# 2025-08-24 04:31:05,389 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_5.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '2097152'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '25fdad14-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:05,556 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:05 GMT'
#     'ETag': '"0x8DDE2C70A4280BC"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669ec3-801e-000c-5baf-14ee8b000000'
#     'x-ms-client-request-id': '25fdad14-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:04 GMT'
# 2025-08-24 04:31:05,557 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_5.csv
# 2025-08-24 04:31:05,559 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/dados_clientes.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '1048576'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '26179bfc-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:05,711 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:05 GMT'
#     'ETag': '"0x8DDE2C70A5A55D0"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669ef5-801e-000c-04af-14ee8b000000'
#     'x-ms-client-request-id': '26179bfc-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:04 GMT'
# 2025-08-24 04:31:05,712 | INFO | Enviado para Azure: processed/2025-08-24_043101/dados_clientes.csv
# 2025-08-24 04:31:05,715 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_4.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '2097152'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '262f62aa-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:05,880 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:05 GMT'
#     'ETag': '"0x8DDE2C70A740714"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669f16-801e-000c-1faf-14ee8b000000'
#     'x-ms-client-request-id': '262f62aa-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:05 GMT'
# 2025-08-24 04:31:05,881 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_4.csv
# 2025-08-24 04:31:05,883 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_6.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '2097152'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '2649214a-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:06,043 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:05 GMT'
#     'ETag': '"0x8DDE2C70A8CCFA4"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669f43-801e-000c-46af-14ee8b000000'
#     'x-ms-client-request-id': '2649214a-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:05 GMT'
# 2025-08-24 04:31:06,044 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_6.csv
# 2025-08-24 04:31:06,048 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/tickets.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '3145728'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '26623ad6-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:06,333 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:06 GMT'
#     'ETag': '"0x8DDE2C70AB92E58"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669f80-801e-000c-79af-14ee8b000000'
#     'x-ms-client-request-id': '26623ad6-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:05 GMT'
# 2025-08-24 04:31:06,335 | INFO | Enviado para Azure: processed/2025-08-24_043101/tickets.csv
# 2025-08-24 04:31:06,337 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/mrr.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '138813'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '268e6494-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:06,473 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:06 GMT'
#     'ETag': '"0x8DDE2C70ACE91EC"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a669fd0-801e-000c-3aaf-14ee8b000000'
#     'x-ms-client-request-id': '268e6494-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:05 GMT'
# 2025-08-24 04:31:06,474 | INFO | Enviado para Azure: processed/2025-08-24_043101/mrr.csv
# 2025-08-24 04:31:06,477 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_8.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '2097152'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '26a3bb5a-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:06,641 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:06 GMT'
#     'ETag': '"0x8DDE2C70AE80E98"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a66a005-801e-000c-68af-14ee8b000000'
#     'x-ms-client-request-id': '26a3bb5a-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:05 GMT'
# 2025-08-24 04:31:06,642 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_8.csv
# 2025-08-24 04:31:06,645 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/nps_relacional.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '886544'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '26bd56d2-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:06,800 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:06 GMT'
#     'ETag': '"0x8DDE2C70B007220"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a66a02a-801e-000c-0aaf-14ee8b000000'
#     'x-ms-client-request-id': '26bd56d2-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:06 GMT'
# 2025-08-24 04:31:06,801 | INFO | Enviado para Azure: processed/2025-08-24_043101/nps_relacional.csv
# 2025-08-24 04:31:06,803 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/nps_transacional_produto.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '1048576'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '26d57adc-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:06,994 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:06 GMT'
#     'ETag': '"0x8DDE2C70B1E0C84"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a66a05b-801e-000c-35af-14ee8b000000'
#     'x-ms-client-request-id': '26d57adc-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:06 GMT'
# 2025-08-24 04:31:06,995 | INFO | Enviado para Azure: processed/2025-08-24_043101/nps_transacional_produto.csv
# 2025-08-24 04:31:06,997 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/nps_transacional_onboarding.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '10329'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '26f313a8-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:07,135 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:07 GMT'
#     'ETag': '"0x8DDE2C70B336E48"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a66a0ab-801e-000c-7baf-14ee8b000000'
#     'x-ms-client-request-id': '26f313a8-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:06 GMT'
# 2025-08-24 04:31:07,136 | INFO | Enviado para Azure: processed/2025-08-24_043101/nps_transacional_onboarding.csv
# 2025-08-24 04:31:07,139 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_9.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '3145728'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '2708ae7a-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:07,417 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:07 GMT'
#     'ETag': '"0x8DDE2C70B5E80CC"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a66a10b-801e-000c-49af-14ee8b000000'
#     'x-ms-client-request-id': '2708ae7a-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:06 GMT'
# 2025-08-24 04:31:07,418 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_9.csv
# 2025-08-24 04:31:07,421 | INFO | Request URL: 'https://totsvisiodb.blob.core.windows.net/csvs-tratados-gpt/processed/2025-08-24_043101/telemetria_3.csv'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '2097152'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.26.0 Python/3.11.5 (Linux-6.5.0-1022-aws-x86_64-with-glibc2.31)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': '2733b598-80a3-11f0-8992-0affe8b339e9'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-08-24 04:31:07,584 | INFO | Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Sun, 24 Aug 2025 04:31:07 GMT'
#     'ETag': '"0x8DDE2C70B77E6D0"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '1a66a196-801e-000c-4aaf-14ee8b000000'
#     'x-ms-client-request-id': '2733b598-80a3-11f0-8992-0affe8b339e9'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Sun, 24 Aug 2025 04:31:06 GMT'
# 2025-08-24 04:31:07,585 | INFO | Enviado para Azure: processed/2025-08-24_043101/telemetria_3.csv
# 2025-08-24 04:31:07,586 | INFO | Upload concluído. 23 arquivo(s) enviados.

# %% [markdown]
# ## Relatório da execução

# %%
import datetime

relatorio = OUTPUT_DIR / f"relatorio_upload_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"
with open(relatorio, "w", encoding="utf-8") as f:
    f.write(f"Execução: {RUN_PREFIX}\n")
    f.write(f"Arquivos processados: {len(tratados)}\n")
    f.write(f"Arquivos enviados: {enviados}\n")
    for p in tratados:
        f.write(f"- {p.name}\n")

logger.info("Relatório salvo em: %s", relatorio)
relatorio
# Out:
# 2025-08-24 04:35:28,325 | INFO | Relatório salvo em: dados_tratados/relatorio_upload_20250824_043528.txt
# PosixPath('dados_tratados/relatorio_upload_20250824_043528.txt')

# %% [markdown]
# ## Relatório do Notebook

# %% [markdown]
# ## Objetivo

# %%
Este notebook implementa um pipeline de tratamento de dados em CSV e upload para um container no Azure Blob Storage.  
Foi desenvolvido para processar arquivos de entrada brutos, gerar versões tratadas e enviá-las automaticamente para a nuvem.

# %% [markdown]
# ## Etapas executadas

# %%
1. Configuração e Logging
   - Definição de diretórios (`dados_originais` e `dados_tratados`)
   - Prefixo único por execução (`processed/YYYY-MM-DD_HHMMSS/`)
   - Logging estruturado para rastrear todas as etapas

2. Verificação de Arquivos CSV
   - Listagem de todos os arquivos `.csv` na pasta `dados_originais`
   - Contagem inicial dos arquivos encontrados
   - Exibição de alguns arquivos para conferência

3. Tratamento de Dados
   - Funções puras e reutilizáveis
   - Normalização de colunas (`snake_case`, `strip` de strings)
   - Conversão conservadora de datas
   - Remoção de duplicatas
   - Relatório de transformações por arquivo

4. Upload para Azure
   - Conexão via `BlobServiceClient` usando *Connection String*
   - Verificação/criação do container
   - Upload dos arquivos tratados para um prefixo único (`processed/...`)
   - Resposta validada pelo status `201 Created`

5. Relatório da Execução
   - Geração de arquivo `.txt` em `dados_tratados/`
   - Contém: execução, número de arquivos processados, número de arquivos enviados, lista de arquivos
   - Exemplo: `relatorio_upload_YYYYMMDD_HHMMSS.txt`

# %% [markdown]
# ## Resultados

# %%
- Arquivos processados e enviados com sucesso para o Azure Blob Storage.  
- Relatório final salvo localmente no diretório `dados_tratados`.

# %% [markdown]
# ## Observações

# %%
- Caso novos arquivos sejam adicionados em `dados_originais`, basta reexecutar o notebook para processar e enviar novamente.
- O container do Azure deve existir ou será criado automaticamente; se já existir, o processo segue normalmente.
- O notebook é modular: pode ser facilmente adaptado para outros diretórios, containers ou até mesmo outros provedores de nuvem.
